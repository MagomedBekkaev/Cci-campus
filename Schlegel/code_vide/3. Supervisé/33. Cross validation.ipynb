# %% [markdown]
# # Validation croisée (cross validation - CV)

# %% [markdown]
# ## Importation des données
# * Commençons par importer les bibliothèques utiles (pandas, numpy, matplotlib)
# * Chargeons un fichier de données contenant l'argent dépensé pour de la publicité et l'impact sur les ventes

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %% [markdown]
# ## Fonction graphique
# * Ajoutons une fonction qui permet de représenter graphiquement les ventes en fonction de chaque paramètre

# %%
def scatter_plot(param):
    plt.figure(figsize=(10,5))
    plt.scatter(data[param], data['Sales'], c='black')
    plt.xlabel(f'Argent dépensé pour des publicités de type {param} (en $)')
    plt.ylabel('Ventes (k$)')
    plt.show()

# %% [markdown]
# ## Visualisation des données
# * Visualisons les ventes en fonction de chaque paramètre pour avoir une première idée

# %% [markdown]
# ## Analyse de la régression linéaire avec CV
# * Utilisation de la fonction helper cross_val_score
#     * cv : Nombre de groupes de données parmi les données initiales

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
# Out:
# [0.87865198 0.91763212 0.92933032 0.81443904 0.89547829]
# 0.8871063495438436

# %% [markdown]
# ## Analyse d'une ridge regression avec CV

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Ridge
# Out:
# 0.8871067777046353

# %% [markdown]
# ## Analyse CV avec variation du paramètre de régularisation
# * Cette fois on donne en plus du nombre de sous groupes une liste de valeurs pour le paramètre de régularisation C
# * La fonction GridSearchCV va nous donner la valeur de paramètre qui a permis de prédire le plus de cas correctement

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
# Out:
# {'alpha': 20}
# 0.8871147941424139

# %% [markdown]
# * Comparons les résultats obtenus entre l'algorithme Ridge et Lasso
#     * le paramètre tol de Lasso est le paramètre de tolérance pour l'optimisation.

# %%
from sklearn.linear_model import Lasso
# Out:
# {'alpha': 1}
# 0.8883861394197915
